# %%
import os
import pandas as pd

# %%
csv_files = []
for file in os.listdir():
    if file.endswith('.csv'):
        csv_files.append(file)

csv_files
# Out:
# ['tweets.csv', 'tweets_old.csv']

# %%
columns = [
    'username',
    'date',
    'text',
    'tags',
    'translated_text',
    'location',
    'latitude',
    'longitude',
    'KADAA_ID',
    'KADAA_AR',
    'KADAA_EN',
    'MOHAFAZA_ID',
    'MOHAFAZA_AR',
    'MOHAFAZA_EN'
]

# %%
main_df = pd.DataFrame(columns=columns)
for file in csv_files:
    df = pd.read_csv(file, header=0)[columns]
    main_df = main_df.append(df.copy())

main_df.to_csv('tweets_data.csv', index=False)

# %%
df = pd.read_csv('tweets_data.csv', header=0)

# %%
df
# Out:
#             username        date  \
# 0       Fouad Badaro  2020-09-05
# 1           الكابتين  2020-09-05
# 2        سفير الشمال  2020-09-05
# 3              Jihad  2020-09-05
# 4       Ali H. Merii  2020-09-05
# ...              ...         ...
# 50478  khazzakanajib  2020-02-05
# 50479   classitudemd  2020-02-03
# 50480     fadykhatib  2020-02-01
# 50481        caseccc  2020-07-29
# 50482           smex  2020-07-26
#
#                                                     text  \
# 0      #Corona #COVIDー19 Official Numbers in Lebanon ...
# 1                           #كورونا_لبنان \n#coronavirus
# 2      إدارة منتجع “البالما” توضح.. ماذا قالت عن إصاب...
# 3      عاجل: وزارة الصحة اللبنانية: 415 إصابة كورونا...
# 4      أخيرا بكرا ٧ ايلول بتخلص التعبئة العامة وبترجع...
# ...                                                  ...
# 50478  حفرت بلدية بيروت الكريمة خنادق عميقة لترسي تصر...
# 50479  Anti vaxxers will always find a way to express...
# 50480  #arms and #medical #industry  rule the world. ...
# 50481  Discounted early registration & abstract submi...
# 50482  ما يهمّ المجتمعات عبر الإنترنت؟ اقترحوا جلسة ل...
#
#                                                     tags  \
# 0      ['#Corona', '#كورونا_لبنان', '#كورونا', '#Stay...
# 1                      ['#كورونا_لبنان', '#coronavirus']
# 2                                  ['#لبنان', '#كورونا']
# 3                                      ['#كورونا_لبنان']
# 4                                      ['#كورونا_لبنان']
# ...                                                  ...
# 50478                                                NaN
# 50479                                                NaN
# 50480  #arms;#medical;#industry;#coronarovirus;#wuhan...
# 50481                             #aio2020;#ai;#oncology
# 50482                                           #خبز_ونت
#
#                                          translated_text location  latitude  \
# 0      #Corona #COVIDー19 Official Numbers in Lebanon ...    بيروت   33.8719
# 1                         # Corona_Lebanon\n#coronavirus    بيروت   33.8719
# 2      The management of the "Palma" resort explains ...      ارة   33.5403
# 3      Urgent: The Lebanese Ministry of Health: 415 C...    حالات   34.0828
# 4      Finally, the 7 of September gets rid of the ge...  المشحاة   34.0500
# ...                                                  ...      ...       ...
# 50478  The honorable municipality of Beirut dug deep ...    بلدية   34.4389
# 50479  Anti vaxxers will always find a way to express...    بيروت   33.8719
# 50480  #arms and #medical #industry  rule the world. ...    بيروت   33.8719
# 50481  Discounted early registration & abstract submi...    بيروت   33.8719
# 50482  What matters to online communities? Propose a ...      مات   34.2183
#
#        longitude  KADAA_ID KADAA_AR     KADAA_EN  MOHAFAZA_ID MOHAFAZA_AR  \
# 0        35.5097     31000    بيروت       Beirut            3       بيروت
# 1        35.5097     31000    بيروت       Beirut            3       بيروت
# 2        35.3800     81000     صيدا        Saida            8      الجنوب
# 3        35.6541     56000     جبيل        Jbeil            5   جبل لبنان
# 4        35.7250     55000   كسروان  Kesserouane            5   جبل لبنان
# ...          ...       ...      ...          ...          ...         ...
# 50478    35.8397     71000   طرابلس      Tripoli            7      الشمال
# 50479    35.5097     31000    بيروت       Beirut            3       بيروت
# 50480    35.5097     31000    بيروت       Beirut            3       بيروت
# 50481    35.5097     31000    بيروت       Beirut            3       بيروت
# 50482    35.7164     74000  البترون   El Batroun            7      الشمال
#
#          MOHAFAZA_EN
# 0             Beirut
# 1             Beirut
# 2              South
# 3      Mount Lebanon
# 4      Mount Lebanon
# ...              ...
# 50478          North
# 50479         Beirut
# 50480         Beirut
# 50481         Beirut
# 50482          North
#
# [50483 rows x 14 columns]
