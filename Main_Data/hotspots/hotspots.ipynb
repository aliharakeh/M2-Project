# %% [markdown]
# # Imports

# %%
import pandas as pd
from difflib import SequenceMatcher

# %% [markdown]
# # 1. Hotspot Words
# - filter gathering related data
# - get nouns
# - check frequencies

# %% [markdown]
# ## 1.1 Get Tweets Related To Gatherings

# %%
with open('words.txt', 'r', encoding='utf-8') as f:
    hotspot_words = f.read().split('\n')

# %%
df = pd.read_csv('all.csv', header=0)

# %%
def hotspot_found(text):
    words = text.split()
    for hotspot_word in hotspot_words:
        for word in words:
            if SequenceMatcher(None, word.lower(), hotspot_word.lower()).ratio() >= 0.8:
                return True
    return False

# %%
hotspots_tweets_mask = df.translated_text.apply(hotspot_found)

# %%
hotspots_tweets_mask.value_counts()

# %%
for x in df[hotspots_tweets_mask].translated_text[:1000]:
    print(x)
    print('------------------------------------')

# %%
df[hotspots_tweets_mask].to_csv('hotspots_tweets_v1.csv', index=False)

# %% [markdown]
# ## 1.2 Get sentences Nouns to filter non location related words

# %%
df = pd.read_csv('hotspots_tweets_v1.csv', header=0)

# %%
from textblob import TextBlob
df['nouns'] = df.translated_text.apply(lambda text: TextBlob(text).noun_phrases)

# %%
df.head()

# %%
df.to_csv('hotspots_tweets_v2.csv')

# %% [markdown]
# ## 1.3 Filter non related nouns

# %%
df = pd.read_csv('hotspots_tweets_v2.csv', header=0)

# %%
nouns = df.nouns.str.replace("[", "").str.replace("]", "").str.split(',').explode().reset_index(drop=True)
nouns

# %%
filter_keywords = ['corona', 'twitter', 'http', 'pic', 'covid_19', 'god', 'covid19', 'd8', 'd9', 'lebanon', 'lebanese', 'covid', 'iran', 'house', 'stayhome', 'medical', 'healthcare', 'ministry', 'syrian', 'home', 'china', 
                  'your', 'syria', 'jordan', 'cases']

first = 1
for keyword in filter_keywords:
    if first:
        filter_condition = nouns.str.contains(keyword)
        first = 0
    else:
        filter_condition |= nouns.str.contains(keyword) 

filter1 = filter_condition
filter1.value_counts()

# %%
filtered_nouns = nouns[~filter1].reset_index(drop=True) # `~` is negation

# %%
filtered_nouns

# %% [markdown]
# ## 1.4 Frequency

# %%
frequencies = filtered_nouns.value_counts()
frequencies

# %%
nouns_df = pd.DataFrame()
nouns_df['noun'] = filtered_nouns
nouns_df['frequency'] = filtered_nouns.replace(frequencies)
nouns_df

# %%
nouns_df[nouns_df.frequency > 100]
# Out:
#                      noun  frequency
# 39       'hamad_hassan20'        241
# 52       'hamad_hassan20'        241
# 76         'saudi arabia'        190
# 94       'hamad_hassan20'        241
# 100           'hezbollah'        217
# ...                   ...        ...
# 121704            'thank'        200
# 121761              'pcr'        136
# 121766           'beirut'        714
# 121815   'aubmc_official'        155
# 121871            'thank'        200
#
# [8845 rows x 2 columns]

# %% [markdown]
# ## 1.5 Conclusion
# - freauencies are not helpful

# %% [markdown]
# # 2. Check keywords (I don't see a future for this ;-;)

# %%
df = pd.read_csv('all.csv', header=0)

# %%
def get_stats(keyword):
    data = df[df.translated_text.str.contains(keyword)].translated_text
    print('`', keyword, '` was found in ', len(data), ' rows')
    print('------------------------------------')
    for d in data:
        print(d)
        print('------------------------------------')

# %%
get_stats('university')

# %%
get_stats('exam')

# %%
get_stats('prison')

# %%
get_stats('shop')

# %%
get_stats('store')

# %%
get_stats('gathering')

# %%
get_stats('eid')

# %%
get_stats('festival')

# %%
get_stats('party')

# %%
get_stats('marriage')

# %% [markdown]
# # 3. Check locations

# %%
with open('location_related_words.txt', 'r', encoding='utf-8') as f:
    location_words = f.read().split('\n')
location_words

# %%
def accepted(phrase):
    word = None
    for w in location_words:
        if w in phrase:
            word = w
            break
    return pd.Series([phrase, word])

filtered_nouns = pd.DataFrame()
filtered_nouns[['phrase', 'location_word']] = nouns.apply(accepted)
filtered_nouns

# %%
a = filtered_nouns[filtered_nouns['location_word'] != 'None']
a

# %% [markdown]
# # 4. Hotspot Words 2

# %%
df = pd.read_csv('all.csv', header=0)

# %%
column = 'text'
column = 'translated_text'

def contains_mask(keyword):
    return df[column].str.lower().str.contains(keyword)

def get_stats(keyword):
    res = contains_mask(keyword).value_counts()
    return keyword + f' ==> {res[1]} rows'

def multi_get_stats(keywords):
    for k in keywords:
        print('- ' + get_stats(k))
        
def get_rows(keyword):
    rows = df[contains_mask(keyword)][column]
    for row in rows:
        print(row)
        print('--------------------')

# %%
multi_get_stats(['university', 'prison', 'marriage', 'shop', 'store', 'تجمعات', 'exam'])
# Out:
# - university ==> 625 rows
# - prison ==> 203 rows
# - marriage ==> 24 rows
# - shop ==> 367 rows
# - store ==> 265 rows
# - تجمعات ==> 3 rows
# - exam ==> 731 rows

# %%
tags = df.tags.str.split(';').explode().reset_index(drop=True)

# %%
freq = tags.value_counts().rename_axis('tag').reset_index(name='counts')
freq
# Out:
#                    tag  counts
# 0        #كورونا_لبنان   14991
# 1              #كورونا   12723
# 2               #لبنان    7550
# 3                 none    7398
# 4             #Lebanon    4597
# ...                ...     ...
# 16856  #twitchstreamer       1
# 16857  #reconnaissance       1
# 16858    #BourjHammoud       1
# 16859         #بوكاشيو       1
# 16860    #مصباح_الأحدب       1
#
# [16861 rows x 2 columns]

# %%
filter_keywords = ['corona', 'كورونا', 'covid', 'lebanon', 'لبنان', 'none', 'خليك_بالبيت', 'خليك_في_البيت', 'healthcare', 'job', 'صباح_الخير', 'medical', 'كوفيد', 'jordan', 'stayhome', 'beirut', 'الصحة', 'بيروت', 'لا_داعي_للهلع', 'الحجر_المنزلي', 'كلن_يعني_كلن', 'dubai', 'health', 'uae', 'حسان_دياب', 'cannabis', 'بلا_مخ']

first = 1
for keyword in filter_keywords:
    if first:
        filter_condition = freq.tag.str.lower().str.contains(keyword.lower())
        first = 0
    else:
        filter_condition |= freq.tag.str.lower().str.contains(keyword) 
    
filtered_freq = freq[~filter_condition].reset_index(drop=True)
filtered_freq
# Out:
#                    tag  count
# 0               #Syria    285
# 1              #Doctor    267
# 2           #صار_الوقت    251
# 3             #Doctors    242
# 4              #center    238
# ...                ...    ...
# 14848  #twitchstreamer      1
# 14849  #reconnaissance      1
# 14850    #BourjHammoud      1
# 14851         #بوكاشيو      1
# 14852    #مصباح_الأحدب      1
#
# [14853 rows x 2 columns]

# %%
filtered_freq[(filtered_freq['count'] >= 100) & (filtered_freq['count'] <= 200)]
# Out:
#                 tag  count
# 13        #refugees    195
# 14       #ما_تستهتر    188
# 15              #UK    185
# 16        #حزب_الله    183
# 17      #medtwitter    182
# 18      #StayAtHome    171
# 19       #marijuana    170
# 20        #staysafe    170
# 21          #hiring    167
# 22       #وطنك_بيتك    150
# 23             #AUB    148
# 24           #Egypt    144
# 25        #Hospital    143
# 26            #عاجل    142
# 27             #DHA    142
# 28             #USA    139
# 29           #ايران    132
# 30           #nurse    130
# 31       #treatment    128
# 32      #مساء_الخير    124
# 33  #التعبئة_العامة    118
# 34            #weed    116
# 35             #مصر    116
# 36     #خليك_بالييت    113
# 37          #Syrian    113
# 38            #HAAD    112
# 39           #إيران    112
# 40              #US    111
# 41              #MD    111
# 42       #Physician    109
# 43           #Saudi    109
# 44          #France    105
# 45          #الكويت    105
# 46          #Jeddah    105
# 47           #الصين    104
# 48      #quarantine    101
# 49          #united    101
# 50            #Iraq    101
# 51    #laboratories    100

# %%
filtered_freq[filtered_freq.tag.str.contains('امتحان')]
# Out:
#                                        tag  count
# 187                        #امتحانات_الموت     41
# 2087                #مقاطعة_امتحانات_الموت      4
# 3028             #لا_لاجراء_امتحانات_رسمية      3
# 5219                   #الامتحانات_الرسمية      2
# 10781  #الغوا_الامتحانات_او_استقبلونا_زوار      1
# 10841            #الغاء_الامتحانات_الرسمية      1
# 11452                            #امتحانات      1
# 11969                  #امتحانات_مش_عاملين      1

# %% [markdown]
# # 5. Hotspots Words 3

# %%
df = pd.read_csv('all.csv', header=0)

# %%
word = 'سجن'
mask = df.text.str.lower().str.contains(word)

# %%
mask.value_counts()
# Out:
# False    51612
# True        71
# Name: text, dtype: int64

# %%
df[mask]
# Out:
#                        username        date  \
# 271              HANZALAH حنظلة  2020-06-16
# 1016     Toni Bayeh طوني البايع  2020-04-01
# 1069      Dany Diab • داني دياب  2020-03-30
# 1401                Fady Khatib  2020-03-21
# 1551   Tammam Nakkash تمام نقاش  2020-03-17
# ...                         ...         ...
# 47863           salehaboushaker  2020-03-07
# 48004           aboufir53160561  2020-03-05
# 48591             tareklebanon1  2020-02-26
# 48624             yorgoelbittar  2020-02-25
# 51002           salehaboushaker  2020-03-07
#
#                                                     text  \
# 271    #كورونا ليس وباء ولا مرض.. إنه تمرين كاذب لترو...
# 1016   اثار الحلاقة  + اثار الحجر الصحي  = نتيجة ما ط...
# 1069   لا إصابات ب #كورونا في سجن رومية، حتّى الوثيقة...
# 1401   @Hassan_B_Diab الاردن منع التجول كلياً تحت رقا...
# 1551   ايران تطلب قرضا من #IMF بقيمة 5 بليون $ لمواجه...
# ...                                                  ...
# 47863  مش بس مات الحلم مات كل شي منحبو بهيدا البلد اص...
# 48004  اربع اصابات بفيروس كورونا بسجن رومية"مبنى د"!و...
# 48591  المعارضة الإيرانية: انتشار " #كورونا في سجني إ...
# 48624  النائب الإصلاحي عن مدينة طهران محمود صادقي يعل...
# 51002  مش بس مات الحلم مات كل شي منحبو بهيدا البلد اص...
#
#                                                     tags  \
# 271                                              #كورونا
# 1016   #حجر_صحي;#تابعونا;#حلاقة_ذقن;#ذقن;#تيك;#سجون;#...
# 1069                            #لبنان;#كورونا;#Covid_19
# 1401                                             #كورونا
# 1551   #بومبيو;#عيب;#يران;#ايران;#العميل_الفاخوري;#كو...
# ...                                                  ...
# 47863    #لبنان_يثور;#لبنان;#تعليق_الدراسة;#كورونا_لبنان
# 48004                                                NaN
# 48591                                            #كورونا
# 48624                                                NaN
# 51002    #لبنان_يثور;#لبنان;#تعليق_الدراسة;#كورونا_لبنان
#
#                                          translated_text  sentiment  location  \
# 271    # Corona is neither a pandemic nor a disease ....  -0.120076       ولا
# 1016   Triggering shaving  + Effects of quarantine  M...   0.100000    الرمول
# 1069   Corona has no injuries in Roumieh prison even ...   0.000000   الغابات
# 1401   @Hassan_B_Diab  Jordan has completely prohibit...   0.100000   العلالي
# 1551   Iran requests a $ 5 billion #IMF loan to meet ...  -0.033333    النشبة
# ...                                                  ...        ...       ...
# 47863  Not, but the dream died, everything died. We l...   0.150000     بيروت
# 48004  Four cases of Corona virus in Roumieh prison "...   0.000000     بيروت
# 48591  The Iranian opposition: The spread of "# Coron...  -0.433333  الشربينة
# 48624  The reformist deputy for the city of Tehran, M...  -0.100000       ايا
# 51002  Not, but the dream died, everything died. We l...   0.150000     بيروت
#
#            lat     long sentiment_label  KADAA_ID KADAA_AR    KADAA_EN  \
# 271    34.5350  36.1814        Negative     11000    عكّار       Akkar
# 1016   34.4331  35.8175        Positive     71000   طرابلس     Tripoli
# 1069   34.0822  35.8733         Neutral     56000     جبيل       Jbeil
# 1401   34.2049  35.7722        Positive     74000  البترون  El Batroun
# 1551   33.4153  35.7472        Negative     64000  حاصبيّا     Hasbaya
# ...        ...      ...             ...       ...      ...         ...
# 47863  33.8719  35.5097        Positive     31000    بيروت      Beirut
# 48004  33.8719  35.5097         Neutral     31000    بيروت      Beirut
# 48591  34.1178  35.8597        Negative     56000     جبيل       Jbeil
# 48624  34.2403  35.7822        Negative     74000  البترون  El Batroun
# 51002  33.8719  35.5097        Positive     31000    بيروت      Beirut
#
#        MOHAFAZA_ID MOHAFAZA_AR    MOHAFAZA_EN
# 271              1        عكار          Akkar
# 1016             7      الشمال          North
# 1069             5   جبل لبنان  Mount Lebanon
# 1401             7      الشمال          North
# 1551             6       نبطية      Nabatiyeh
# ...            ...         ...            ...
# 47863            3       بيروت         Beirut
# 48004            3       بيروت         Beirut
# 48591            5   جبل لبنان  Mount Lebanon
# 48624            7      الشمال          North
# 51002            3       بيروت         Beirut
#
# [71 rows x 16 columns]
